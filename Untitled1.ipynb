# %%
import pandas as pd
import psycopg2 as psp

# %%
conn = psp.connect(
            database='diabete',
            user = 'hugofugeray',
            password = 'postgres',
            host = 'localhost',
            port = '5432'
        )
c = conn.cursor()

# %%
c.execute('''SELECT valeurs.valeur AS valeur, symptomes.facteur AS facteur, patient.diabete_binary AS diabete_binary, patient_id FROM valeurs
  JOIN patient
  ON patient_id = patient.id
  JOIN symptomes
  ON symptome_id = symptomes.id;''')

df_init = c.fetchall()

data = pd.DataFrame(df_init)

data.rename(columns={0: "valeur", 1: "facteur", 2 :'diabetes_binary', 3 : 'patient'}, inplace = True)

# %%
df = data.pivot(index = ['patient', 'diabetes_binary'], columns='facteur', values='valeur')

# %%
df.reset_index('diabetes_binary', inplace=True)

# %%
df
# Out:
# facteur  diabetes_binary  Age  AnyHealthcare  BMI  CholCheck  DiffWalk  \
# patient
# 1                      0    9              1   40          1         1
# 2                      0    7              0   25          0         0
# 3                      0    9              1   28          1         1
# 4                      0   11              1   27          1         0
# 5                      0   11              1   24          1         0
# ...                  ...  ...            ...  ...        ...       ...
# 253676                 0    5              1   45          1         0
# 253677                 1   11              1   18          1         1
# 253678                 0    2              1   28          1         0
# 253679                 0    7              1   23          1         0
# 253680                 1    9              1   25          1         0
#
# facteur  Education  Fruits  GenHlth  HeartDiseaseorAttack  ...  \
# patient                                                    ...
# 1                4       0        5                     0  ...
# 2                6       0        3                     0  ...
# 3                4       1        5                     0  ...
# 4                3       1        2                     0  ...
# 5                5       1        2                     0  ...
# ...            ...     ...      ...                   ...  ...
# 253676           6       1        3                     0  ...
# 253677           2       0        4                     0  ...
# 253678           5       1        1                     0  ...
# 253679           5       1        3                     0  ...
# 253680           6       1        2                     1  ...
#
# facteur  HvyAlcoholConsump  Income  MentHlth  NoDocbcCost  PhysActivity  \
# patient
# 1                        0       3        18            0             0
# 2                        0       1         0            1             1
# 3                        0       8        30            1             0
# 4                        0       6         0            0             1
# 5                        0       4         3            0             1
# ...                    ...     ...       ...          ...           ...
# 253676                   0       7         0            0             0
# 253677                   0       4         0            0             0
# 253678                   0       2         0            0             1
# 253679                   0       1         0            0             0
# 253680                   0       2         0            0             1
#
# facteur  PhysHlth  Sex  Smoker  Stroke  Veggies
# patient
# 1              15    0       1       0        1
# 2               0    0       1       0        0
# 3              30    0       0       0        0
# 4               0    0       0       0        1
# 5               0    0       0       0        1
# ...           ...  ...     ...     ...      ...
# 253676          5    1       0       0        1
# 253677          0    0       0       0        0
# 253678          0    0       0       0        0
# 253679          0    1       0       0        1
# 253680          0    0       0       0        0
#
# [253680 rows x 22 columns]

# %%
user_input = 'db ou modele ?'
user_input
# Out:
# 'db ou modele ?'
